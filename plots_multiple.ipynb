# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

gm0_df = pd.read_csv(f'results/longest_two_gamma0.csv')
gm0_df_miner0 = gm0_df[:51]
gm0_df_miner1 = gm0_df[51:101]
gm0_df_miner2 = gm0_df[101:151]
gm0_df_miner3 = gm0_df[151:201]
gm0_df_miner4 = gm0_df[201:251]

gm05_df = pd.read_csv(f'results/longest_two_gamma05.csv')
gm05_df_miner0 = gm05_df[:51]
gm05_df_miner1 = gm05_df[51:101]
gm05_df_miner2 = gm05_df[101:151]
gm05_df_miner3 = gm05_df[151:201]
gm05_df_miner4 = gm05_df[201:251]

gm1_df = pd.read_csv(f'results/longest_two_gamma1.csv')
gm1_df_miner0 = gm1_df[:51]
gm1_df_miner1 = gm1_df[51:101]
gm1_df_miner2 = gm1_df[101:151]
gm1_df_miner3 = gm1_df[151:201]
gm1_df_miner4 = gm1_df[201:251]

fig, axs = plt.subplots(1, 3, figsize=(24, 6))

# plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain 2 miners longest chain rule')

axs[0].grid()
axs[1].grid()
axs[2].grid()

axs[0].set_title('Gamma = 0.0')
axs[1].set_title('Gamma = 0.5')
axs[2].set_title('Gamma = 1.0')

axs[0].set_xlabel('Mining power of Attacker 1 [%]')
axs[1].set_xlabel('Mining power of Attacker 1 [%]')
axs[2].set_xlabel('Mining power of Attacker 1 [%]')

axs[0].set_ylabel('Reward of Attacker 1 [%]')
axs[1].set_ylabel('Reward of Attacker 1 [%]')
axs[2].set_ylabel('Reward of Attacker 1 [%]')

axs[0].plot(gm0_df_miner0['selfish_miner_power'].to_numpy(), gm0_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[0].plot(gm0_df_miner0['selfish_miner_power'].to_numpy(), gm0_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[0].plot(gm0_df_miner1['selfish_miner_power'].to_numpy(), gm0_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[0].plot(gm0_df_miner2['selfish_miner_power'].to_numpy(), gm0_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[0].plot(gm0_df_miner3['selfish_miner_power'].to_numpy(), gm0_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[0].plot(gm0_df_miner4['selfish_miner_power'].to_numpy(), gm0_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[0].legend()

axs[1].plot(gm05_df_miner0['selfish_miner_power'].to_numpy(), gm05_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[1].plot(gm05_df_miner0['selfish_miner_power'].to_numpy(), gm05_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[1].plot(gm05_df_miner1['selfish_miner_power'].to_numpy(), gm05_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[1].plot(gm05_df_miner2['selfish_miner_power'].to_numpy(), gm05_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[1].plot(gm05_df_miner3['selfish_miner_power'].to_numpy(), gm05_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[1].plot(gm05_df_miner4['selfish_miner_power'].to_numpy(), gm05_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[1].legend()

axs[2].plot(gm1_df_miner0['selfish_miner_power'].to_numpy(), gm1_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[2].plot(gm1_df_miner0['selfish_miner_power'].to_numpy(), gm1_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[2].plot(gm1_df_miner1['selfish_miner_power'].to_numpy(), gm1_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[2].plot(gm1_df_miner2['selfish_miner_power'].to_numpy(), gm1_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[2].plot(gm1_df_miner3['selfish_miner_power'].to_numpy(), gm1_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[2].plot(gm1_df_miner4['selfish_miner_power'].to_numpy(), gm1_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[2].legend()

plt.show()
fig.savefig('fruitchain_longest_two_miners.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

gm0_df = pd.read_csv(f'results/strongest_two_gamma0.csv')
gm0_df_miner0 = gm0_df[:51]
gm0_df_miner1 = gm0_df[51:101]
gm0_df_miner2 = gm0_df[101:151]
gm0_df_miner3 = gm0_df[151:201]
gm0_df_miner4 = gm0_df[201:251]

gm05_df = pd.read_csv(f'results/strongest_two_gamma05.csv')
gm05_df_miner0 = gm05_df[:51]
gm05_df_miner1 = gm05_df[51:101]
gm05_df_miner2 = gm05_df[101:151]
gm05_df_miner3 = gm05_df[151:201]
gm05_df_miner4 = gm05_df[201:251]

gm1_df = pd.read_csv(f'results/strongest_two_gamma1.csv')
gm1_df_miner0 = gm1_df[:51]
gm1_df_miner1 = gm1_df[51:101]
gm1_df_miner2 = gm1_df[101:151]
gm1_df_miner3 = gm1_df[151:201]
gm1_df_miner4 = gm1_df[201:251]

fig, axs = plt.subplots(1, 3, figsize=(24, 6))

# plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain 2 miners strongest chain rule')

axs[0].grid()
axs[1].grid()
axs[2].grid()

axs[0].set_title('Gamma = 0.0')
axs[1].set_title('Gamma = 0.5')
axs[2].set_title('Gamma = 1.0')

axs[0].set_xlabel('Mining power of Attacker 1 [%]')
axs[1].set_xlabel('Mining power of Attacker 1 [%]')
axs[2].set_xlabel('Mining power of Attacker 1 [%]')

axs[0].set_ylabel('Reward of Attacker 1 [%]')
axs[1].set_ylabel('Reward of Attacker 1 [%]')
axs[2].set_ylabel('Reward of Attacker 1 [%]')

axs[0].plot(gm0_df_miner0['selfish_miner_power'].to_numpy(), gm0_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[0].plot(gm0_df_miner0['selfish_miner_power'].to_numpy(), gm0_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[0].plot(gm0_df_miner1['selfish_miner_power'].to_numpy(), gm0_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[0].plot(gm0_df_miner2['selfish_miner_power'].to_numpy(), gm0_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[0].plot(gm0_df_miner3['selfish_miner_power'].to_numpy(), gm0_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[0].plot(gm0_df_miner4['selfish_miner_power'].to_numpy(), gm0_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[0].legend()

axs[1].plot(gm05_df_miner0['selfish_miner_power'].to_numpy(), gm05_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[1].plot(gm05_df_miner0['selfish_miner_power'].to_numpy(), gm05_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[1].plot(gm05_df_miner1['selfish_miner_power'].to_numpy(), gm05_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[1].plot(gm05_df_miner2['selfish_miner_power'].to_numpy(), gm05_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[1].plot(gm05_df_miner3['selfish_miner_power'].to_numpy(), gm05_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[1].plot(gm05_df_miner4['selfish_miner_power'].to_numpy(), gm05_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[1].legend()

axs[2].plot(gm1_df_miner0['selfish_miner_power'].to_numpy(), gm1_df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
axs[2].plot(gm1_df_miner0['selfish_miner_power'].to_numpy(), gm1_df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attacker 2 = 0%')
axs[2].plot(gm1_df_miner1['selfish_miner_power'].to_numpy(), gm1_df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attacker 2 = 10%')
axs[2].plot(gm1_df_miner2['selfish_miner_power'].to_numpy(), gm1_df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attacker 2 = 20%')
axs[2].plot(gm1_df_miner3['selfish_miner_power'].to_numpy(), gm1_df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attacker 2 = 30%')
axs[2].plot(gm1_df_miner4['selfish_miner_power'].to_numpy(), gm1_df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attacker 2 = 40%')
axs[2].legend()

plt.show()
fig.savefig('fruitchain_strongest_two_miners.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv(f'results/longest_three_data.csv')
df_miner0 = df[:51]
df_miner1 = df[51:101]
df_miner2 = df[101:151]
df_miner3 = df[151:201]
df_miner4 = df[201:251]

fig, ax = plt.subplots(figsize=(8,6))
# plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})
fig.set_facecolor('white')

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain longest chain rule')

ax.grid()

# ax.set_title('Fruitchain longest chain rule with 3 selfish miners')
ax.set_xlabel('Mining power of Attacker 1 [%]')
ax.set_ylabel('Reward of Attacker 1 [%]')

ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attackers 2 and 3 = 0%')
ax.plot(df_miner1['selfish_miner_power'].to_numpy(), df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attackers 2 and 3 = 10%')
ax.plot(df_miner2['selfish_miner_power'].to_numpy(), df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attackers 2 and 3 = 20%')
ax.plot(df_miner3['selfish_miner_power'].to_numpy(), df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attackers 2 and 3 = 30%')
ax.plot(df_miner4['selfish_miner_power'].to_numpy(), df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attackers 2 and 3 = 40%')
ax.legend()

plt.show()
fig.savefig('fruit_longest_three.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv(f'results/longest_five_data.csv')
df_miner0 = df[:51]
df_miner1 = df[51:101]
df_miner2 = df[101:151]
df_miner3 = df[151:201]
df_miner4 = df[201:251]

fig, ax = plt.subplots(figsize=(8,6))
# plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})
fig.set_facecolor('white')

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain longest chain rule')

ax.grid()

# ax.set_title('Fruitchain longest chain rule with 5 selfish miners')
ax.set_xlabel('Mining power of Attacker 1 [%]')
ax.set_ylabel('Reward of Attacker 1 [%]')

ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 0%')
ax.plot(df_miner1['selfish_miner_power'].to_numpy(), df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 10%')
ax.plot(df_miner2['selfish_miner_power'].to_numpy(), df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 20%')
ax.plot(df_miner3['selfish_miner_power'].to_numpy(), df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 30%')
ax.plot(df_miner4['selfish_miner_power'].to_numpy(), df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 40%')
ax.legend()

plt.show()
fig.savefig('fruit_longest_five.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv(f'results/strongest_three_data.csv')
df_miner0 = df[:51]
df_miner1 = df[51:101]
df_miner2 = df[101:151]
df_miner3 = df[151:201]
df_miner4 = df[201:251]

fig, ax = plt.subplots(figsize=(8,6))
# plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})
fig.set_facecolor('white')

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain longest chain rule')

ax.grid()

# ax.set_title('Fruitchain strongest chain rule with 3 selfish miners')
ax.set_xlabel('Mining power of Attacker 1 [%]')
ax.set_ylabel('Reward of Attacker 1 [%]')

ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attackers 2 and 3 = 0%')
ax.plot(df_miner1['selfish_miner_power'].to_numpy(), df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attackers 2 and 3 = 10%')
ax.plot(df_miner2['selfish_miner_power'].to_numpy(), df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attackers 2 and 3 = 20%')
ax.plot(df_miner3['selfish_miner_power'].to_numpy(), df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attackers 2 and 3 = 30%')
ax.plot(df_miner4['selfish_miner_power'].to_numpy(), df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attackers 2 and 3 = 40%')
ax.legend()

plt.show()
fig.savefig('fruit_strongest_three.pdf')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv(f'results/strongest_five_data.csv')
df_miner0 = df[:51]
df_miner1 = df[51:101]
df_miner2 = df[101:151]
df_miner3 = df[151:201]
df_miner4 = df[201:251]

fig, ax = plt.subplots(figsize=(8,6))
# plt.rcParams['figure.dpi'] = 200
plt.rcParams.update({'font.size': 12})
fig.set_facecolor('white')

# fig.subplots_adjust(top=0.8)
# fig.suptitle('Fruitchain longest chain rule')

ax.grid()

# ax.set_title('Fruitchain strongest chain rule with 5 selfish miners')
ax.set_xlabel('Mining power of Attacker 1 [%]')
ax.set_ylabel('Reward of Attacker 1 [%]')

ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['selfish_miner_power'].to_numpy(), '--', color='gray', linewidth=1.0, label='Baseline')
ax.plot(df_miner0['selfish_miner_power'].to_numpy(), df_miner0['profit'].to_numpy(), 'r', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 0%')
ax.plot(df_miner1['selfish_miner_power'].to_numpy(), df_miner1['profit'].to_numpy(), 'c', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 10%')
ax.plot(df_miner2['selfish_miner_power'].to_numpy(), df_miner2['profit'].to_numpy(), 'm', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 20%')
ax.plot(df_miner3['selfish_miner_power'].to_numpy(), df_miner3['profit'].to_numpy(), 'y', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 30%')
ax.plot(df_miner4['selfish_miner_power'].to_numpy(), df_miner4['profit'].to_numpy(), 'b', linewidth=2.0, label='Power of Attackers 2, 3, 4, and 5 = 40%')
ax.legend()

plt.show()
fig.savefig('fruit_strongest_five.pdf')
